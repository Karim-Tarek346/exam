# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Karim Tarek**
#
# High School student

# %% [markdown]
# *I am interested in data science because it is well paid*
#
# *Also I am interseted in data science because it is a challenge for me to learn beside my school studies*

# %% [markdown]
# ### My code should print hello world

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ___
#
# 1. Number one
# 2. Number two
# 3. Number three
#
# |name||Age|
# |---||---|
# |Karim||15|
#
# <code>
# print("Hello world")
# </code>
